# %%
import numpy as np
import pandas as pd
import os
pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
import gc
from math import sqrt
from sklearn.metrics import roc_auc_score
import pickle

import lightgbm as lgb
import math as mt
from math import *
import matplotlib as mlp
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
import seaborn as sns
from tqdm import tqdm

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_predict


import joblib
import random
import itertools
import scipy as sp

from itertools import combinations
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
class CFG:
    seed = 42
    n_folds = 5
    target = 'target'
    input_dir = '../src/data/processed/'
    dpv = 'v6'
    mv = 'v2'

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

def read_data():
    train = pd.read_parquet(CFG.input_dir + 'train_fe_rich.parquet')
    test = pd.read_parquet(CFG.input_dir + 'test_fe_rich.parquet')
    return train, test

def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

def amex_metric_np(preds, target):
    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]
    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / np.sum(target)
    weighted_target = target * weight
    lorentz = (weighted_target / weighted_target.sum()).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()
    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos
    gini_max = 10 * n_neg * (n_pos + 20 * n_neg - 19) / (n_pos + 20 * n_neg)
    g = gini / gini_max
    return 0.5 * (g + d)

# %%
seed_everything(CFG.seed)
df_train, df_test = read_data()
df_train.shape, df_test.shape
# Out:
# ((458913, 2539), (924621, 2538))

# %%
num_cols = list(df_train.dtypes[(df_train.dtypes == 'float32') | (df_train.dtypes == 'float64')].index)
len(num_cols)
# Out:
# 1894

# %%
cat_cols = ['B_30','B_38','D_114','D_116','D_117','D_120','D_126','D_63','D_64','D_66','D_68']
cat_features = [f"{cf}_last" for cf in cat_cols]

# %%
# user_cat = ['B_30_last','B_38_last']
# add_cat = ['D_114_last','D_116_last','D_117_last','D_120_last','D_126_last','D_63_last','D_64_last','D_66_last',
#            'D_68_last']

# print('len cat cols:', len(cat_features))
# for c1 in user_cat:
    
#     df_train[c1] = df_train[c1].astype('str')
#     df_test[c1] = df_test[c1].astype('str')
    
#     for c2 in add_cat:
#         df_train[c2] = df_train[c2].astype('str')
#         df_test[c2] = df_test[c2].astype('str')
#         df_train[c1+'_and_'+c2] = df_train[c1].astype('str') + '_and_' + df_train[c2].astype('str')
#         df_test[c1+'_and_'+c2] = df_test[c1].astype('str') + '_and_' + df_test[c2].astype('str')
#         cat_features.append(c1+'_and_'+c2)
        
# print('len cat cols:', len(cat_features))

# %%
# print('len cat cols:', len(cat_features))

# for i1 in range(len(add_cat)-1):
#     for i2 in range(i1+1, len(add_cat)):
#         c1 = add_cat[i1]
#         c2 = add_cat[i2]

#         df_train[c1+'_and_'+c2] = df_train[c1].astype('str') + '_and_' + df_train[c2].astype('str')
#         df_test[c1+'_and_'+c2] = df_test[c1].astype('str') + '_and_' + df_test[c2].astype('str')
#         cat_features.append(c1+'_and_'+c2)

# print('len cat cols:', len(cat_features))

# %%
for cat_col in cat_features:
    
    x = len(list(set(df_test[cat_col].unique()))), 
    y = len(list(set(df_train[cat_col].unique())))
    if x!=y:
        print(f'Fixing {cat_col}')
        a = df_test[cat_col].unique()
        b = df_train[cat_col].unique()
        mv = df_train[cat_col].mode()[0]
        df_test[cat_col] = np.where(df_test[cat_col].isin(b), df_test[cat_col], mv)
        
        x = df_test[cat_col].unique() 
        y = df_train[cat_col].unique()
        
        for cat in x:
            if cat not in y:
                print('Doomed')
                print(cat_col)
                break
# Out:
# Fixing B_30_last
# Fixing B_38_last
# Fixing D_114_last
# Fixing D_116_last
# Fixing D_117_last
# Fixing D_120_last
# Fixing D_126_last
# Fixing D_63_last
# Fixing D_64_last
# Fixing D_66_last
# Fixing D_68_last

# %%
for cat_col in cat_features:
    encoder = LabelEncoder()
    df_train[cat_col] = encoder.fit_transform(df_train[cat_col])
    df_test[cat_col] = encoder.transform(df_test[cat_col])
    
df_train.shape, df_test.shape
# Out:
# ((458913, 2539), (924621, 2538))

# %%
# rcols = ['P_2','B_9','D_44','D_48','B_2','B_1','B_11','B_37','B_3','B_18','R_1','D_41','S_23','S_3','B_4',
#          'R_2','B_7','D_41','D_39','D_42','D_48']
# rcols = [f"{cf}_last" for cf in rcols]

# %%
# for col in rcols:
#     try:
#         df_train['ROUND_'+col] = df_train[col].round(2)
#         df_test['ROUND_'+col] = df_test[col].round(2)
#     except:
#         pass

# df_train.shape, df_test.shape

# %%
def add_stats(data, feats, type_col):
    
    cols = feats
    type_col = type_col.upper()
    data[type_col+'_f_min']   = data[cols].fillna(0).min(axis = 1)
    data[type_col+'_f_max']   = data[cols].fillna(0).max(axis = 1)
    data[type_col+'_f_mean']  = data[cols].fillna(0).mean(axis = 1)
    data[type_col+'_f_sd']    = data[cols].fillna(0).std(axis = 1).round(2)
    data[type_col+'_f_sum']   = data[cols].fillna(0).sum(axis = 1).round(2)
    data[type_col+'_f_skew']  = data[cols].fillna(0).skew(axis = 1).round(2)
    data[type_col+'_f_gtone']  = data[cols].gt(1).sum(axis=1)
    data[type_col+'_f_gttwo']  = data[cols].gt(2).sum(axis=1)
    data[type_col+'_f_gtfour']  = data[cols].gt(4).sum(axis=1)
    data[type_col+'_f_gteight']  = data[cols].gt(8).sum(axis=1)
    data[type_col+'_f_gtsixteen']  = data[cols].gt(16).sum(axis=1)
    data[type_col+'_f_meanone_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gtone']-data[type_col+'_f_mean'])
    data[type_col+'_f_meantwo_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gttwo']-data[type_col+'_f_mean'])
    data[type_col+'_f_meanfour_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gtfour']-data[type_col+'_f_mean'])
    data[type_col+'_f_meaneight_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gteight']-data[type_col+'_f_mean'])
    data[type_col+'_f_meansixteen_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gtsixteen']-data[type_col+'_f_mean'])
    
    data = data.drop([type_col+'_f_gtone',type_col+'_f_gttwo',
                      type_col+'_f_gtfour',type_col+'_f_gteight',type_col+'_f_gtsixteen'], axis=1)
    
    return data

# %%
typecol = 'last'
df_train = add_stats(df_train, [col for col in num_cols if 'last' in col and col not in cat_features], typecol)
df_test = add_stats(df_test, [col for col in num_cols if 'last' in col and col not in cat_features], typecol)

df_train.shape, df_test.shape
# Out:
# ((458913, 2550), (924621, 2549))

# %%
typecol = 'round'
df_train = add_stats(df_train,[col for col in num_cols if 'round_' in col and col not in cat_features],typecol)
df_test = add_stats(df_test,[col for col in num_cols if 'round_' in col and col not in cat_features],typecol)

df_train.shape, df_test.shape
# Out:
# ((458913, 2561), (924621, 2560))

# %%
typecol = 'mean'
df_train = add_stats(df_train, [col for col in num_cols if 'mean' in col and col not in cat_features],typecol)
df_test = add_stats(df_test, [col for col in num_cols if 'mean' in col and col not in cat_features],typecol)

df_train.shape, df_test.shape
# Out:
# ((458913, 2572), (924621, 2571))

# %%
X_train = df_train.drop(['customer_ID'], axis=1)
X_test = df_test.drop(['customer_ID'], axis=1)
Y_train = df_train['target']

# %%
X_train.shape, X_test.shape
# Out:
# ((458913, 2571), (924621, 2570))

# %%
# # Get the difference between last and mean
# num_cols = [col for col in df_train.columns if 'last' in col]
# num_cols = [col[:-5] for col in num_cols if 'round' not in col]

num_cols = [col for col in df_train.columns if 'last' in col]
num_cols = [col for col in num_cols if 'lag' not in col]
num_cols = [col for col in num_cols if 'round' not in col]
num_cols = [col for col in num_cols if 'last_f_' not in col]
num_cols = [col[:-5] for col in num_cols]

print(len(num_cols))
l = 0
for col in num_cols:
    try:
        X_train[f'{col}_last_mean_diff'] = X_train[f'{col}_last'] - X_train[f'{col}_mean']
        X_test[f'{col}_last_mean_diff'] = X_test[f'{col}_last'] - X_test[f'{col}_mean']
        X_train[f'{col}_last_max_diff'] = X_train[f'{col}_last'] - X_train[f'{col}_max']
        X_test[f'{col}_last_max_diff'] = X_test[f'{col}_last'] - X_test[f'{col}_max']
        X_train[f'{col}_L3Mean_last_mean_diff'] = X_train[f'{col}_L3Mmean'] - X_train[f'{col}_mean']
        X_test[f'{col}_L3Mean_last_mean_diff'] = X_test[f'{col}_L3Mmean'] - X_test[f'{col}_mean']
        X_train[f'{col}_last_L3Max_R'] = X_train[f'{col}_last']/X_train[f'{col}_L3Mmax']
        X_test[f'{col}_last_L3Max_R'] = X_test[f'{col}_last']/X_test[f'{col}_L3Mmax']
        
        l = l+1
    except:
        pass
    
print(l)
# Out:
# 188
# 177

# %%
X_train.shape, X_test.shape
# Out:
# ((458913, 3279), (924621, 3278))

# %%
params = {
    'objective': 'binary',
    'boosting': 'dart',
    'seed': CFG.seed,
    'num_leaves': 100,
    'learning_rate': 0.01,
    'feature_fraction': 0.824,
    'bagging_freq': 10,
    'bagging_fraction': 0.40,
    'n_jobs': -1,
    'lambda_l2': 2,
    'min_data_in_leaf': 40,
    'verbose': -1,
    'metric': 'amex_metric',
}

# %%
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

test_predictions = np.zeros(len(X_test))
oof_predictions = np.zeros(len(X_train))

kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
for fold, (trn_ind, val_ind) in enumerate(kfold.split(X_train, Y_train)):
            
    print(' ')
    print('-'*50)
    print(f'Training fold {fold}:-')

    x_train, x_val = X_train.drop('target', axis=1).iloc[trn_ind], X_train.drop('target', axis=1).iloc[val_ind]
    y_train, y_val = Y_train.iloc[trn_ind], Y_train.iloc[val_ind]

    lgb_train = lgb.Dataset(x_train, y_train, categorical_feature = cat_features)
    lgb_valid = lgb.Dataset(x_val, y_val, categorical_feature = cat_features)

    print('X_train shape:', x_train.shape)
    print('X_valid shape:', x_val.shape)
    print('X_test shape:', X_test.shape)

    if fold <= CFG.n_folds-1:
#     if fold > 0:

        model = lgb.train(
            params = params,
            train_set = lgb_train,
            num_boost_round = 9000,
            valid_sets = [lgb_train, lgb_valid],
            verbose_eval = 500,
            feval = lgb_amex_metric,
            )
    
        joblib.dump(model, f'../src/models/BinaryModels/lgb_{CFG.mv}_dp{CFG.dpv}_fold{fold}_seed{CFG.seed}.pkl')
        print(lgb.plot_importance(model, max_num_features=50, importance_type='gain', figsize=(12,18)))

    else:
        with open(f'../src/models/BinaryModels/lgb_{CFG.mv}_dp{CFG.dpv}_fold{fold}_seed{CFG.seed}.pkl', 'rb') as f:
            model = pickle.load(f)
        print(lgb.plot_importance(model, max_num_features=50, importance_type='gain', figsize=(12,18)))

    # Predict validation
    val_pred = model.predict(x_val)
    # Add to out of folds array
    oof_predictions[val_ind] = val_pred
    # Predict the test set
    test_pred = model.predict(X_test)
    test_predictions += test_pred / CFG.n_folds
    # Compute fold metric
    score = amex_metric(y_val, val_pred)
    print(f'Our fold {fold} CV score is {score}')
    del x_train, x_val, y_train, y_val, lgb_train, lgb_valid
    gc.collect()
    
# Our fold 0 CV score is 0.801870357674788
# Our fold 1 CV score is 0.79323304112139
# Our fold 2 CV score is 0.7966604839748368
# Our fold 3 CV score is 0.7930946495362687
# Our fold 4 CV score is 0.7970017904748772
# Out:
#
# --------------------------------------------------
# Training fold 0:-
# X_train shape: (367130, 3278)
# X_valid shape: (91783, 3278)
# X_test shape: (924621, 3278)
# [500]	training's amex_metric: 0.779747	valid_1's amex_metric: 0.770124
# [1000]	training's amex_metric: 0.799802	valid_1's amex_metric: 0.78258
# [1500]	training's amex_metric: 0.816271	valid_1's amex_metric: 0.789711
# [2000]	training's amex_metric: 0.830921	valid_1's amex_metric: 0.79587
# [2500]	training's amex_metric: 0.842637	valid_1's amex_metric: 0.797161
# [3000]	training's amex_metric: 0.853462	valid_1's amex_metric: 0.799041
# [3500]	training's amex_metric: 0.865767	valid_1's amex_metric: 0.799635
# [4000]	training's amex_metric: 0.876877	valid_1's amex_metric: 0.800355
# [4500]	training's amex_metric: 0.887927	valid_1's amex_metric: 0.801144
# [5000]	training's amex_metric: 0.89813	valid_1's amex_metric: 0.800115
# [5500]	training's amex_metric: 0.907707	valid_1's amex_metric: 0.800926
# [6000]	training's amex_metric: 0.916398	valid_1's amex_metric: 0.801857
# [6500]	training's amex_metric: 0.924415	valid_1's amex_metric: 0.801177
# [7000]	training's amex_metric: 0.933262	valid_1's amex_metric: 0.801091
# [7500]	training's amex_metric: 0.941725	valid_1's amex_metric: 0.802186
# [8000]	training's amex_metric: 0.948737	valid_1's amex_metric: 0.801205
# [8500]	training's amex_metric: 0.955052	valid_1's amex_metric: 0.800883
# [9000]	training's amex_metric: 0.960984	valid_1's amex_metric: 0.80187
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 0 CV score is 0.801870357674788
#
# --------------------------------------------------
# Training fold 1:-
# X_train shape: (367130, 3278)
# X_valid shape: (91783, 3278)
# X_test shape: (924621, 3278)
# [500]	training's amex_metric: 0.781197	valid_1's amex_metric: 0.762663
# [1000]	training's amex_metric: 0.801688	valid_1's amex_metric: 0.774517
# [1500]	training's amex_metric: 0.817523	valid_1's amex_metric: 0.781014
# [2000]	training's amex_metric: 0.832508	valid_1's amex_metric: 0.785295
# [2500]	training's amex_metric: 0.844086	valid_1's amex_metric: 0.787924
# [3000]	training's amex_metric: 0.855413	valid_1's amex_metric: 0.79029
# [3500]	training's amex_metric: 0.867034	valid_1's amex_metric: 0.791059
# [4000]	training's amex_metric: 0.878148	valid_1's amex_metric: 0.792408
# [4500]	training's amex_metric: 0.889131	valid_1's amex_metric: 0.791959
# [5000]	training's amex_metric: 0.900074	valid_1's amex_metric: 0.793161
# [5500]	training's amex_metric: 0.909479	valid_1's amex_metric: 0.79364
# [6000]	training's amex_metric: 0.918148	valid_1's amex_metric: 0.792883
# [6500]	training's amex_metric: 0.926051	valid_1's amex_metric: 0.794441
# [7000]	training's amex_metric: 0.934167	valid_1's amex_metric: 0.794466
# [7500]	training's amex_metric: 0.942679	valid_1's amex_metric: 0.794731
# [8000]	training's amex_metric: 0.949169	valid_1's amex_metric: 0.794596
# [8500]	training's amex_metric: 0.955847	valid_1's amex_metric: 0.794134
# [9000]	training's amex_metric: 0.961706	valid_1's amex_metric: 0.793233
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 1 CV score is 0.79323304112139
#
# --------------------------------------------------
# Training fold 2:-
# X_train shape: (367130, 3278)
# X_valid shape: (91783, 3278)
# X_test shape: (924621, 3278)
# [500]	training's amex_metric: 0.779932	valid_1's amex_metric: 0.76635
# [1000]	training's amex_metric: 0.801296	valid_1's amex_metric: 0.780375
# [1500]	training's amex_metric: 0.816491	valid_1's amex_metric: 0.787112
# [2000]	training's amex_metric: 0.832008	valid_1's amex_metric: 0.791042
# [2500]	training's amex_metric: 0.843776	valid_1's amex_metric: 0.793998
# [3000]	training's amex_metric: 0.856073	valid_1's amex_metric: 0.795201
# [3500]	training's amex_metric: 0.867352	valid_1's amex_metric: 0.795624
# [4000]	training's amex_metric: 0.878645	valid_1's amex_metric: 0.796382
# [4500]	training's amex_metric: 0.889516	valid_1's amex_metric: 0.796413
# [5000]	training's amex_metric: 0.899277	valid_1's amex_metric: 0.796106
# [5500]	training's amex_metric: 0.908737	valid_1's amex_metric: 0.796774
# [6000]	training's amex_metric: 0.91738	valid_1's amex_metric: 0.797075
# [6500]	training's amex_metric: 0.925055	valid_1's amex_metric: 0.796071
# [7000]	training's amex_metric: 0.934073	valid_1's amex_metric: 0.796317
# [7500]	training's amex_metric: 0.94203	valid_1's amex_metric: 0.795892
# [8000]	training's amex_metric: 0.948986	valid_1's amex_metric: 0.796476
# [8500]	training's amex_metric: 0.95585	valid_1's amex_metric: 0.796319
# [9000]	training's amex_metric: 0.961841	valid_1's amex_metric: 0.79666
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 2 CV score is 0.7966604839748368
#
# --------------------------------------------------
# Training fold 3:-
# X_train shape: (367131, 3278)
# X_valid shape: (91782, 3278)
# X_test shape: (924621, 3278)
# [500]	training's amex_metric: 0.781879	valid_1's amex_metric: 0.762933
# [1000]	training's amex_metric: 0.801768	valid_1's amex_metric: 0.773724
# [1500]	training's amex_metric: 0.817745	valid_1's amex_metric: 0.780197
# [2000]	training's amex_metric: 0.833364	valid_1's amex_metric: 0.784293
# [2500]	training's amex_metric: 0.844929	valid_1's amex_metric: 0.78721
# [3000]	training's amex_metric: 0.855935	valid_1's amex_metric: 0.789191
# [3500]	training's amex_metric: 0.867308	valid_1's amex_metric: 0.79021
# [4000]	training's amex_metric: 0.877939	valid_1's amex_metric: 0.790714
# [4500]	training's amex_metric: 0.888398	valid_1's amex_metric: 0.79151
# [5000]	training's amex_metric: 0.898671	valid_1's amex_metric: 0.79146
# [5500]	training's amex_metric: 0.90876	valid_1's amex_metric: 0.791744
# [6000]	training's amex_metric: 0.917537	valid_1's amex_metric: 0.791426
# [6500]	training's amex_metric: 0.925125	valid_1's amex_metric: 0.79154
# [7000]	training's amex_metric: 0.933943	valid_1's amex_metric: 0.792455
# [7500]	training's amex_metric: 0.942043	valid_1's amex_metric: 0.79265
# [8000]	training's amex_metric: 0.949109	valid_1's amex_metric: 0.792616
# [8500]	training's amex_metric: 0.955787	valid_1's amex_metric: 0.793156
# [9000]	training's amex_metric: 0.961909	valid_1's amex_metric: 0.793095
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 3 CV score is 0.7930946495362687
#
# --------------------------------------------------
# Training fold 4:-
# X_train shape: (367131, 3278)
# X_valid shape: (91782, 3278)
# X_test shape: (924621, 3278)
# [500]	training's amex_metric: 0.780507	valid_1's amex_metric: 0.765501
# [1000]	training's amex_metric: 0.800714	valid_1's amex_metric: 0.778648
# [1500]	training's amex_metric: 0.816634	valid_1's amex_metric: 0.783908
# [2000]	training's amex_metric: 0.831207	valid_1's amex_metric: 0.789266
# [2500]	training's amex_metric: 0.842891	valid_1's amex_metric: 0.790971
# [3000]	training's amex_metric: 0.854515	valid_1's amex_metric: 0.793281
# [3500]	training's amex_metric: 0.866538	valid_1's amex_metric: 0.795319
# [4000]	training's amex_metric: 0.878323	valid_1's amex_metric: 0.795541
# [4500]	training's amex_metric: 0.888658	valid_1's amex_metric: 0.797128
# [5000]	training's amex_metric: 0.898815	valid_1's amex_metric: 0.797991
# [5500]	training's amex_metric: 0.908523	valid_1's amex_metric: 0.79781
# [6000]	training's amex_metric: 0.916923	valid_1's amex_metric: 0.798652
# [6500]	training's amex_metric: 0.924885	valid_1's amex_metric: 0.79817
# [7000]	training's amex_metric: 0.933481	valid_1's amex_metric: 0.798014
# [7500]	training's amex_metric: 0.941731	valid_1's amex_metric: 0.798649
# [8000]	training's amex_metric: 0.948875	valid_1's amex_metric: 0.798677
# [8500]	training's amex_metric: 0.955448	valid_1's amex_metric: 0.79843
# [9000]	training's amex_metric: 0.961039	valid_1's amex_metric: 0.798195
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 4 CV score is 0.7981951260909088

# %%
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# test_predictions = np.zeros(len(X_test))
# oof_predictions = np.zeros(len(X_train))

kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
for fold, (trn_ind, val_ind) in enumerate(kfold.split(X_train, Y_train)):
    
    if fold==1:
        print(' ')
        print('-'*50)
        print(f'Training fold {fold}:-')

        x_train, x_val = X_train.drop('target', axis=1).iloc[trn_ind], X_train.drop('target', axis=1).iloc[val_ind]
        y_train, y_val = Y_train.iloc[trn_ind], Y_train.iloc[val_ind]

        lgb_train = lgb.Dataset(x_train, y_train, categorical_feature = cat_features)
        lgb_valid = lgb.Dataset(x_val, y_val, categorical_feature = cat_features)

        print('X_train shape:', x_train.shape)
        print('X_valid shape:', x_val.shape)
        print('X_test shape:', X_test.shape)

#         with open(f'../src/models/BinaryModels/lgb_{CFG.mv}_dp{CFG.dpv}_fold{fold}_seed{CFG.seed}.pkl', 'rb') as f:
#             model = pickle.load(f)

#         test_pred = model.predict(X_test)
#         test_predictions -= test_pred / CFG.n_folds

        model = lgb.train(
            params = params,
            train_set = lgb_train,
            num_boost_round = 7500,
            valid_sets = [lgb_train, lgb_valid],
            verbose_eval = 500,
            feval = lgb_amex_metric,
            )
    
        joblib.dump(model, f'../src/models/BinaryModels/lgbn_{CFG.mv}_dp{CFG.dpv}_fold{fold}_seed{CFG.seed}.pkl')
        print(lgb.plot_importance(model, max_num_features=50, importance_type='gain', figsize=(12,18)))
        
        # Predict validation
        val_pred = model.predict(x_val)
        # Add to out of folds array
        oof_predictions[val_ind] = val_pred
        # Predict the test set
        test_pred = model.predict(X_test)
        test_predictions += test_pred / CFG.n_folds
        # Compute fold metric
        score = amex_metric(y_val, val_pred)
        print(f'Our fold {fold} CV score is {score}')
        del x_train, x_val, y_train, y_val, lgb_train, lgb_valid
        gc.collect()

# Our fold 1 CV score is 0.79323304112139
# Out:
#
# --------------------------------------------------
# Training fold 1:-
# X_train shape: (367130, 3278)
# X_valid shape: (91783, 3278)
# X_test shape: (924621, 3278)
# [500]	training's amex_metric: 0.781197	valid_1's amex_metric: 0.762663
# [1000]	training's amex_metric: 0.801688	valid_1's amex_metric: 0.774517
# [1500]	training's amex_metric: 0.817523	valid_1's amex_metric: 0.781014
# [2000]	training's amex_metric: 0.832508	valid_1's amex_metric: 0.785295
# [2500]	training's amex_metric: 0.844086	valid_1's amex_metric: 0.787924
# [3000]	training's amex_metric: 0.855413	valid_1's amex_metric: 0.79029
# [3500]	training's amex_metric: 0.867034	valid_1's amex_metric: 0.791059
# [4000]	training's amex_metric: 0.878148	valid_1's amex_metric: 0.792408
# [4500]	training's amex_metric: 0.889131	valid_1's amex_metric: 0.791959
# [5000]	training's amex_metric: 0.900074	valid_1's amex_metric: 0.793161
# [5500]	training's amex_metric: 0.909479	valid_1's amex_metric: 0.79364
# [6000]	training's amex_metric: 0.918148	valid_1's amex_metric: 0.792883
# [6500]	training's amex_metric: 0.926051	valid_1's amex_metric: 0.794441
# [7000]	training's amex_metric: 0.934167	valid_1's amex_metric: 0.794466
# [7500]	training's amex_metric: 0.942679	valid_1's amex_metric: 0.794731
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 1 CV score is 0.7947312833236383

# %%
# Compute out of folds metric
score = amex_metric(Y_train, oof_predictions)
print(f'Our out of folds CV score is {score}')

oof_filename = f'OOFs/oof_{CFG.mv}_dp{CFG.dpv}{CFG.n_folds}fold_seed{CFG.seed}.csv'
tst_filename = f'PREDs/lgb_{CFG.mv}_dp{CFG.dpv}{CFG.n_folds}fold_seed{CFG.seed}.csv'

# Create a dataframe to store out of folds predictions
oof_df = pd.DataFrame({'customer_ID': df_train['customer_ID'], 'target': Y_train, 'prediction': oof_predictions})
oof_df.to_csv(oof_filename, index = False)

# Create a dataframe to store test prediction
test_df = pd.DataFrame({'customer_ID': df_test['customer_ID'], 'prediction': test_predictions})
test_df.to_csv(tst_filename, index = False)
print(tst_filename)
# Out:
# Our out of folds CV score is 0.7967187149710697
# PREDs/lgb_v2_dpv65fold_seed42.csv

# %%
# !kaggle competitions submit -c amex-default-prediction -f cb_v2_dpv25fold_seed802.csv -m "catboost with \
# 2008 feats CV 7952"
