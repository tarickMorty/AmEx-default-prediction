# %%
import numpy as np
import pandas as pd
import os
pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
import gc
from math import sqrt
from sklearn.metrics import roc_auc_score
import pickle

import lightgbm as lgb
import math as mt
from math import *
import matplotlib as mlp
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
import seaborn as sns
from tqdm import tqdm

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_predict


import joblib
import random
import itertools
import scipy as sp

from itertools import combinations
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
class CFG:
    seed = 4242
    n_folds = 5
    target = 'target'
    input_dir = '../src/data/processed/'
    dpv = 'v6'
    mv = 'v1'

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

def read_data():
    train = pd.read_parquet(CFG.input_dir + 'train_fe_rich.parquet')
    test = pd.read_parquet(CFG.input_dir + 'test_fe_rich.parquet')
#     test['D_86_last'] = np.where(test['D_86_last']==-1, 0, test['D_86_last'])
    return train, test

def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

def amex_metric_np(preds, target):
    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]
    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / np.sum(target)
    weighted_target = target * weight
    lorentz = (weighted_target / weighted_target.sum()).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()
    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos
    gini_max = 10 * n_neg * (n_pos + 20 * n_neg - 19) / (n_pos + 20 * n_neg)
    g = gini / gini_max
    return 0.5 * (g + d)

# %%
def filter_date(trn, tst):
    
    df_1 = trn.copy()
    df_2 = tst.copy()
    
    t1 = pd.read_parquet('../src/data/raw/train.parquet', columns = ['customer_ID','S_2'])
    t1['monthyear'] = (pd.to_datetime(t1['S_2']).dt.year.astype(str)+
                      pd.to_datetime(t1['S_2']).dt.month.map("{:02}".format).astype(str))
    x = t1.groupby("customer_ID")['monthyear'].agg(['nunique'])
    df_1 = df_1[df_1.customer_ID.isin(x[x['nunique']<13].index)].reset_index(drop=True)
    
    del t1, x
    
    t1 = pd.read_parquet('../src/data/raw/test.parquet', columns = ['customer_ID','S_2'])
    t1['monthyear'] = (pd.to_datetime(t1['S_2']).dt.year.astype(str)+
                      pd.to_datetime(t1['S_2']).dt.month.map("{:02}".format).astype(str))
    x = t1.groupby("customer_ID")['monthyear'].agg(['nunique'])
    df_2 = df_2[df_2.customer_ID.isin(x[x['nunique']<13].index)].reset_index(drop=True)
    
    del t1, x
    
    return df_1, df_2

# %%
seed_everything(CFG.seed)
df_train, df_test = read_data()
df_train.shape, df_test.shape
# Out:
# ((458913, 2539), (924621, 2538))

# %%
df_train, df_test = filter_date(df_train, df_test)
df_train.shape, df_test.shape
# Out:
# ((72879, 2539), (113292, 2538))

# %%
num_cols = list(df_train.dtypes[(df_train.dtypes == 'float32') | (df_train.dtypes == 'float64')].index)
len(num_cols)
# Out:
# 1894

# %%
cat_cols = ['B_30','B_38','D_114','D_116','D_117','D_120','D_126','D_63','D_64','D_66','D_68']
cat_features = [f"{cf}_last" for cf in cat_cols]

# %%
user_cat = ['B_30_last','B_38_last']
add_cat = ['D_114_last','D_116_last','D_117_last','D_120_last','D_126_last','D_63_last','D_64_last','D_66_last',
           'D_68_last']

print('len cat cols:', len(cat_features))
for c1 in user_cat:
    
    df_train[c1] = df_train[c1].astype('str')
    df_test[c1] = df_test[c1].astype('str')
    
    for c2 in add_cat:
        df_train[c2] = df_train[c2].astype('str')
        df_test[c2] = df_test[c2].astype('str')
        df_train[c1+'_and_'+c2] = df_train[c1].astype('str') + '_and_' + df_train[c2].astype('str')
        df_test[c1+'_and_'+c2] = df_test[c1].astype('str') + '_and_' + df_test[c2].astype('str')
        cat_features.append(c1+'_and_'+c2)
        
print('len cat cols:', len(cat_features))
# Out:
# len cat cols: 11
# len cat cols: 29

# %%
print('len cat cols:', len(cat_features))

for i1 in range(len(add_cat)-1):
    for i2 in range(i1+1, len(add_cat)):
        c1 = add_cat[i1]
        c2 = add_cat[i2]

        df_train[c1+'_and_'+c2] = df_train[c1].astype('str') + '_and_' + df_train[c2].astype('str')
        df_test[c1+'_and_'+c2] = df_test[c1].astype('str') + '_and_' + df_test[c2].astype('str')
        cat_features.append(c1+'_and_'+c2)

print('len cat cols:', len(cat_features))
# Out:
# len cat cols: 29
# len cat cols: 65

# %%
for cat_col in cat_features:
    
    x = len(list(set(df_test[cat_col].unique()))), 
    y = len(list(set(df_train[cat_col].unique())))
    if x!=y:
        print(f'Fixing {cat_col}')
        a = df_test[cat_col].unique()
        b = df_train[cat_col].unique()
        mv = df_train[cat_col].mode()[0]
        df_test[cat_col] = np.where(df_test[cat_col].isin(b), df_test[cat_col], mv)
        
        x = df_test[cat_col].unique() 
        y = df_train[cat_col].unique()
        
        for cat in x:
            if cat not in y:
                print('Doomed')
                print(cat_col)
                break
# Out:
# Fixing B_30_last
# Fixing B_38_last
# Fixing D_114_last
# Fixing D_116_last
# Fixing D_117_last
# Fixing D_120_last
# Fixing D_126_last
# Fixing D_63_last
# Fixing D_64_last
# Fixing D_66_last
# Fixing D_68_last
# Fixing B_30_last_and_D_114_last
# Fixing B_30_last_and_D_116_last
# Fixing B_30_last_and_D_117_last
# Fixing B_30_last_and_D_120_last
# Fixing B_30_last_and_D_126_last
# Fixing B_30_last_and_D_63_last
# Fixing B_30_last_and_D_64_last
# Fixing B_30_last_and_D_66_last
# Fixing B_30_last_and_D_68_last
# Fixing B_38_last_and_D_114_last
# Fixing B_38_last_and_D_116_last
# Fixing B_38_last_and_D_117_last
# Fixing B_38_last_and_D_120_last
# Fixing B_38_last_and_D_126_last
# Fixing B_38_last_and_D_63_last
# Fixing B_38_last_and_D_64_last
# Fixing B_38_last_and_D_66_last
# Fixing B_38_last_and_D_68_last
# Fixing D_114_last_and_D_116_last
# Fixing D_114_last_and_D_117_last
# Fixing D_114_last_and_D_120_last
# Fixing D_114_last_and_D_126_last
# Fixing D_114_last_and_D_63_last
# Fixing D_114_last_and_D_64_last
# Fixing D_114_last_and_D_66_last
# Fixing D_114_last_and_D_68_last
# Fixing D_116_last_and_D_117_last
# Fixing D_116_last_and_D_120_last
# Fixing D_116_last_and_D_126_last
# Fixing D_116_last_and_D_63_last
# Fixing D_116_last_and_D_64_last
# Fixing D_116_last_and_D_66_last
# Fixing D_116_last_and_D_68_last
# Fixing D_117_last_and_D_120_last
# Fixing D_117_last_and_D_126_last
# Fixing D_117_last_and_D_63_last
# Fixing D_117_last_and_D_64_last
# Fixing D_117_last_and_D_66_last
# Fixing D_117_last_and_D_68_last
# Fixing D_120_last_and_D_126_last
# Fixing D_120_last_and_D_63_last
# Fixing D_120_last_and_D_64_last
# Fixing D_120_last_and_D_66_last
# Fixing D_120_last_and_D_68_last
# Fixing D_126_last_and_D_63_last
# Fixing D_126_last_and_D_64_last
# Fixing D_126_last_and_D_66_last
# Fixing D_126_last_and_D_68_last
# Fixing D_63_last_and_D_64_last
# Fixing D_63_last_and_D_66_last
# Fixing D_63_last_and_D_68_last
# Fixing D_64_last_and_D_66_last
# Fixing D_64_last_and_D_68_last
# Fixing D_66_last_and_D_68_last

# %%
for cat_col in cat_features:
    encoder = LabelEncoder()
    df_train[cat_col] = encoder.fit_transform(df_train[cat_col])
    df_test[cat_col] = encoder.transform(df_test[cat_col])

# %%
df_train.shape, df_test.shape
# Out:
# ((72879, 2593), (113292, 2592))

# %%
rcols = ['P_2','B_9','D_44','D_48','B_2','B_1','B_11','B_37','B_3','B_18','R_1','D_41','S_23','S_3','B_4',
         'R_2','B_7','D_41','D_39','D_42','D_48']
rcols = [f"{cf}_last" for cf in rcols]

# %%
for col in rcols:
    try:
        df_train['round_'+col] = df_train[col].round(2)
        df_test['round_'+col] = df_test[col].round(2)
    except:
        pass

# %%
df_train.shape, df_test.shape
# Out:
# ((72879, 2612), (113292, 2611))

# %%
def add_stats(data, feats, type_col):
    
    cols = feats
    data[type_col+'_f_min']   = data[cols].fillna(0).min(axis = 1).round(2)
    data[type_col+'_f_max']   = data[cols].fillna(0).max(axis = 1).round(2)
    data[type_col+'_f_mean']  = data[cols].fillna(0).mean(axis = 1).round(2)
    data[type_col+'_f_sd']    = data[cols].fillna(0).std(axis = 1).round(2)
    data[type_col+'_f_sum']   = data[cols].fillna(0).sum(axis = 1).round(2)
    data[type_col+'_f_skew']  = data[cols].fillna(0).skew(axis = 1).round(2)
    data[type_col+'_f_gtone']  = data[cols].gt(1).sum(axis=1)
    data[type_col+'_f_gttwo']  = data[cols].gt(2).sum(axis=1)
    data[type_col+'_f_gtfour']  = data[cols].gt(4).sum(axis=1)
    data[type_col+'_f_gteight']  = data[cols].gt(8).sum(axis=1)
    data[type_col+'_f_gtsixteen']  = data[cols].gt(16).sum(axis=1)
    data[type_col+'_f_meanone_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gtone']-data[type_col+'_f_mean'])
    data[type_col+'_f_meantwo_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gttwo']-data[type_col+'_f_mean'])
    data[type_col+'_f_meanfour_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gtfour']-data[type_col+'_f_mean'])
    data[type_col+'_f_meaneight_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gteight']-data[type_col+'_f_mean'])
    data[type_col+'_f_meansixteen_meandiff'] = (data[type_col+'_f_sum']/data[type_col+'_f_gtsixteen']-data[type_col+'_f_mean'])
    
    data = data.drop([type_col+'_f_gtone',type_col+'_f_gttwo',
                      type_col+'_f_gtfour',type_col+'_f_gteight',type_col+'_f_gtsixteen'], axis=1)
    
    return data

# %%
typecol = 'last'
df_train = add_stats(df_train, [col for col in num_cols if 'last' in col and col not in cat_features], typecol)
df_test = add_stats(df_test, [col for col in num_cols if 'last' in col and col not in cat_features], typecol)

df_train.shape, df_test.shape
# Out:
# ((72879, 2623), (113292, 2622))

# %%
typecol = 'round'
df_train = add_stats(df_train,[col for col in num_cols if 'round_' in col and col not in cat_features],typecol)
df_test = add_stats(df_test,[col for col in num_cols if 'round_' in col and col not in cat_features],typecol)

df_train.shape, df_test.shape
# Out:
# ((72879, 2634), (113292, 2633))

# %%
typecol = 'mean'
df_train = add_stats(df_train, [col for col in num_cols if 'mean' in col and col not in cat_features],typecol)
df_test = add_stats(df_test, [col for col in num_cols if 'mean' in col and col not in cat_features],typecol)

df_train.shape, df_test.shape
# Out:
# ((72879, 2645), (113292, 2644))

# %%
typecol = 'min'
df_train = add_stats(df_train, [col for col in num_cols if 'min' in col and col not in cat_features],typecol)
df_test = add_stats(df_test, [col for col in num_cols if 'min' in col and col not in cat_features],typecol)

df_train.shape, df_test.shape
# Out:
# ((72879, 2656), (113292, 2655))

# %%
typecol = 'max'
df_train = add_stats(df_train, [col for col in num_cols if 'max' in col and col not in cat_features],typecol)
df_test = add_stats(df_test, [col for col in num_cols if 'max' in col and col not in cat_features],typecol)

df_train.shape, df_test.shape
# Out:
# ((72879, 2667), (113292, 2666))

# %%
# merge_cat_enc = True

# if merge_cat_enc:
    
#     dt_trn = pd.read_parquet(CFG.input_dir + 'train_cat_enc_5fold_seed37.parquet')
#     df_train = df_train.merge(dt_trn, on='customer_ID', how='left')
    
#     del dt_trn
#     gc.collect()
    
#     dt_tst = pd.read_parquet(CFG.input_dir + 'test_cat_enc_5fold_seed37.parquet')
#     df_test = df_test.merge(dt_tst, on='customer_ID', how='left')
    
#     del dt_tst
#     gc.collect()
    
# df_train.shape, df_test.shape

# %%
# merge_date = False

# if merge_date:
    
#     dt_trn = pd.read_parquet(CFG.input_dir + 'dt_trn.parquet')
#     df_train = df_train.merge(dt_trn, on='customer_ID', how='left')
    
#     del dt_trn
#     gc.collect()
    
#     dt_tst = pd.read_parquet(CFG.input_dir + 'dt_tst.parquet')
#     df_test = df_test.merge(dt_tst, on='customer_ID', how='left')
    
#     del dt_tst
#     gc.collect()
    
# df_train.shape, df_test.shape

# %%
t1 = pd.read_parquet('../src/data/raw/train.parquet', columns = ['customer_ID','S_2'])
t1['monthyear'] = (pd.to_datetime(t1['S_2']).dt.year.astype(str)+
                  pd.to_datetime(t1['S_2']).dt.month.map("{:02}".format).astype(str))
x = t1.groupby("customer_ID")['monthyear'].agg(['nunique'])
x = x.reset_index()
x.columns = ['customer_ID', 'nrows']
del t1

df_train = pd.merge(df_train, x, on='customer_ID', how='left')
del x

split_train = df_train['target'].astype(str) + df_train['nrows'].astype(str)

# %%
X_train = df_train.drop(['customer_ID', 'nrows'], axis=1)
X_test = df_test.drop(['customer_ID'], axis=1)
Y_train = df_train['target']

# %%
X_train.shape, X_test.shape
# Out:
# ((72879, 2666), (113292, 2665))

# %%
# Get the difference between last and mean
# num_cols = [col for col in df_train.columns if 'last' in col]
# num_cols = [col[:-5] for col in num_cols if 'round' not in col]

num_cols = [col for col in df_train.columns if 'last' in col]
num_cols = [col for col in num_cols if 'lag' not in col]
num_cols = [col for col in num_cols if 'round' not in col]
num_cols = [col for col in num_cols if 'last_f_' not in col]
num_cols = [col[:-5] for col in num_cols]

print(len(num_cols))
l = 0
for col in num_cols:
    try:
        X_train[f'{col}_last_mean_diff'] = X_train[f'{col}_last'] - X_train[f'{col}_mean']
        X_test[f'{col}_last_mean_diff'] = X_test[f'{col}_last'] - X_test[f'{col}_mean']
#         X_train[f'{col}_last_first_R'] = X_train[f'{col}_last']/X_train[f'{col}_first']
#         X_test[f'{col}_last_first_R'] = X_test[f'{col}_last']/X_test[f'{col}_first']
#         X_train[f'{col}_last_mean_R'] = X_train[f'{col}_last']/X_train[f'{col}_mean']
#         X_test[f'{col}_last_mean_R'] = X_test[f'{col}_last']/X_test[f'{col}_mean']
        X_train[f'{col}_last_max_diff'] = X_train[f'{col}_last'] - X_train[f'{col}_max']
        X_test[f'{col}_last_max_diff'] = X_test[f'{col}_last'] - X_test[f'{col}_max']
#         X_train[f'{col}_last_max_R'] = X_train[f'{col}_last']/X_train[f'{col}_max']
#         X_test[f'{col}_last_max_R'] = X_test[f'{col}_last']/X_test[f'{col}_max']
#         X_train[f'{col}_max_mean_R'] = X_train[f'{col}_max']/X_train[f'{col}_mean']
#         X_test[f'{col}_max_mean_R'] = X_test[f'{col}_max']/X_test[f'{col}_mean']
        l = l+1
    except:
        pass
    
print(l)
# Out:
# 242
# 177

# %%
class DartEarlyStopping(object):
    """DartEarlyStopping"""

    def __init__(self, data_name, monitor_metric, stopping_round):
        self.data_name = data_name
        self.monitor_metric = monitor_metric
        self.stopping_round = stopping_round
        self.best_score = None
        self.best_model = None
        self.best_score_list = []
        self.best_iter = 0

    def _is_higher_score(self, metric_score, is_higher_better):
        if self.best_score is None:
            return True
        return (self.best_score < metric_score) if is_higher_better else (self.best_score > metric_score)

    def _deepcopy(self, x):
        return pickle.loads(pickle.dumps(x))

    def __call__(self, env):
        evals = env.evaluation_result_list
        for data, metric, score, is_higher_better in evals:
            if data != self.data_name or metric != self.monitor_metric:
                continue
            if not self._is_higher_score(score, is_higher_better):
                if env.iteration - self.best_iter > self.stopping_round:
                    eval_result_str = '\t'.join([lgb.callback._format_eval_result(x) for x in self.best_score_list])
                    lgb.basic._log_info(f"Early stopping, best iteration is:\n[{self.best_iter+1}]\t{eval_result_str}") 
                    lgb.basic._log_info(f"You can get best model by \"DartEarlyStopping.best_model\"")
                    raise lgb.callback.EarlyStopException(self.best_iter, self.best_score_list)
                return
            self.best_model = self._deepcopy(env.model)
            self.best_iter = env.iteration
            self.best_score_list = evals
            self.best_score = score
            return
        raise ValueError("monitoring metric not found")

# %%
# params = {
#     'objective': 'binary',
#     'boosting': 'dart',
#     'seed': CFG.seed,
#     'num_leaves': 100,
#     'learning_rate': 0.01,
#     'feature_fraction': 0.20,
#     'bagging_freq': 8,
#     'bagging_fraction': 0.40,
#     'n_jobs': -1,
#     'lambda_l2': 2,
#     'min_data_in_leaf': 40,
#     'verbose': -1,
# #     'metric': "binary_logloss", 
#     'metric': 'amex_metric',
# #     'first_metric_only': True,
#     }

params = {
    'objective': 'binary',
    'boosting': 'dart',
    'seed': CFG.seed,
    'num_leaves': 63,
    'learning_rate': 0.008,
    'feature_fraction': 1,
    'bagging_freq': 8,
    'bagging_fraction': 0.40,
    'n_jobs': -1,
    'lambda_l2': 15,
    'min_data_in_leaf': 16,
    'verbose': -1,
#     'metric': "binary_logloss", 
    'metric': 'amex_metric',
#     'first_metric_only': True,
    }

# %%
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# Create a numpy array to store test predictions
test_predictions = np.zeros(len(X_test))
# Create a numpy array to store out of folds predictions
oof_predictions = np.zeros(len(X_train))

kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
# for fold, (trn_ind, val_ind) in enumerate(kfold.split(X_train, Y_train)):
for fold, (trn_ind, val_ind) in enumerate(kfold.split(X_train, split_train)):

#     if fold>4:
    print(' ')
    print('-'*50)
    print(f'Training fold {fold}:-')

    x_train, x_val = X_train.drop('target', axis=1).iloc[trn_ind], X_train.drop('target', axis=1).iloc[val_ind]
    y_train, y_val = Y_train.iloc[trn_ind], Y_train.iloc[val_ind]

    lgb_train = lgb.Dataset(x_train, y_train, categorical_feature = cat_features)
    lgb_valid = lgb.Dataset(x_val, y_val, categorical_feature = cat_features)

    print('X_train shape:', x_train.shape)
    print('X_valid shape:', x_val.shape)
    print('X_test shape:', X_test.shape)
    
    if fold <= CFG.n_folds-1:
#     if fold>0:

        des = DartEarlyStopping("valid_1", "amex_metric", 750)
    
        model = lgb.train(
            params = params,
            train_set = lgb_train,
            num_boost_round = 10000,
            valid_sets = [lgb_train, lgb_valid],
            verbose_eval = 500,
            feval = lgb_amex_metric,
#             callbacks=[des],
            )        
        print(lgb.plot_importance(model, max_num_features=50, importance_type='gain', figsize=(12,18)))

        # Save best model
        joblib.dump(model, 
                    f'../src/models/BinaryModels/lgb_lt12_{CFG.mv}_dp{CFG.dpv}_fold{fold}_seed{CFG.seed}.pkl')

    else:
        with open(f'../src/models/BinaryModels/lgb_lt12_{CFG.mv}_dp{CFG.dpv}_fold{fold}_seed{CFG.seed}.pkl', 
                  'rb') as f:
            model = pickle.load(f)
            print(lgb.plot_importance(model, max_num_features=50, importance_type='gain', figsize=(12,18)))

    # Predict validation
    val_pred = model.predict(x_val)
    # Add to out of folds array
    oof_predictions[val_ind] = val_pred
    # Predict the test set
    test_pred = model.predict(X_test)
    test_predictions += test_pred / CFG.n_folds
    # Compute fold metric
    score = amex_metric(y_val, val_pred)
    print(f'Our fold {fold} CV score is {score}')
    del x_train, x_val, y_train, y_val, lgb_train, lgb_valid
    gc.collect()
    
# Our fold 0 CV score is 0.6614437623379978
# Out:
#
# --------------------------------------------------
# Training fold 0:-
# X_train shape: (58303, 3019)
# X_valid shape: (14576, 3019)
# X_test shape: (113292, 3019)
# [500]	training's amex_metric: 0.667687	valid_1's amex_metric: 0.631269
# [1000]	training's amex_metric: 0.693521	valid_1's amex_metric: 0.645827
# [1500]	training's amex_metric: 0.720472	valid_1's amex_metric: 0.651885
# [2000]	training's amex_metric: 0.744794	valid_1's amex_metric: 0.654721
# [2500]	training's amex_metric: 0.77052	valid_1's amex_metric: 0.655604
# [3000]	training's amex_metric: 0.792571	valid_1's amex_metric: 0.655805
# [3500]	training's amex_metric: 0.812215	valid_1's amex_metric: 0.658287
# [4000]	training's amex_metric: 0.83261	valid_1's amex_metric: 0.65811
# [4500]	training's amex_metric: 0.848935	valid_1's amex_metric: 0.659933
# [5000]	training's amex_metric: 0.864449	valid_1's amex_metric: 0.660161
# [5500]	training's amex_metric: 0.881737	valid_1's amex_metric: 0.658878
# [6000]	training's amex_metric: 0.897048	valid_1's amex_metric: 0.660528
# [6500]	training's amex_metric: 0.910418	valid_1's amex_metric: 0.660592
# [7000]	training's amex_metric: 0.92216	valid_1's amex_metric: 0.659753
# [7500]	training's amex_metric: 0.934031	valid_1's amex_metric: 0.658714
# [8000]	training's amex_metric: 0.945083	valid_1's amex_metric: 0.658912
# [8500]	training's amex_metric: 0.954538	valid_1's amex_metric: 0.654502
# [9000]	training's amex_metric: 0.960919	valid_1's amex_metric: 0.654985
# [9500]	training's amex_metric: 0.96809	valid_1's amex_metric: 0.654674
# [10000]	training's amex_metric: 0.974008	valid_1's amex_metric: 0.654433
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 0 CV score is 0.654432649748778
#
# --------------------------------------------------
# Training fold 1:-
# X_train shape: (58303, 3019)
# X_valid shape: (14576, 3019)
# X_test shape: (113292, 3019)
# [500]	training's amex_metric: 0.663981	valid_1's amex_metric: 0.633305
# [1000]	training's amex_metric: 0.694923	valid_1's amex_metric: 0.643897
# [1500]	training's amex_metric: 0.720037	valid_1's amex_metric: 0.649227
# [2000]	training's amex_metric: 0.74487	valid_1's amex_metric: 0.652924
# [2500]	training's amex_metric: 0.768608	valid_1's amex_metric: 0.656023
# [3000]	training's amex_metric: 0.791415	valid_1's amex_metric: 0.658769
# [3500]	training's amex_metric: 0.812085	valid_1's amex_metric: 0.660791
# [4000]	training's amex_metric: 0.830938	valid_1's amex_metric: 0.660782
# [4500]	training's amex_metric: 0.847996	valid_1's amex_metric: 0.660321
# [5000]	training's amex_metric: 0.862299	valid_1's amex_metric: 0.662403
# [5500]	training's amex_metric: 0.880044	valid_1's amex_metric: 0.660919
# [6000]	training's amex_metric: 0.89323	valid_1's amex_metric: 0.661868
# [6500]	training's amex_metric: 0.906047	valid_1's amex_metric: 0.660664
# [7000]	training's amex_metric: 0.919289	valid_1's amex_metric: 0.65899
# [7500]	training's amex_metric: 0.9311	valid_1's amex_metric: 0.660432
# [8000]	training's amex_metric: 0.942291	valid_1's amex_metric: 0.660247
# [8500]	training's amex_metric: 0.951136	valid_1's amex_metric: 0.659868
# [9000]	training's amex_metric: 0.958621	valid_1's amex_metric: 0.661041
# [9500]	training's amex_metric: 0.967033	valid_1's amex_metric: 0.660515
# [10000]	training's amex_metric: 0.972811	valid_1's amex_metric: 0.660136
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 1 CV score is 0.6601356882690859
#
# --------------------------------------------------
# Training fold 2:-
# X_train shape: (58303, 3019)
# X_valid shape: (14576, 3019)
# X_test shape: (113292, 3019)
# [500]	training's amex_metric: 0.668591	valid_1's amex_metric: 0.628583
# [1000]	training's amex_metric: 0.692824	valid_1's amex_metric: 0.642523
# [1500]	training's amex_metric: 0.719257	valid_1's amex_metric: 0.649985
# [2000]	training's amex_metric: 0.742847	valid_1's amex_metric: 0.652092
# [2500]	training's amex_metric: 0.767818	valid_1's amex_metric: 0.655595
# [3000]	training's amex_metric: 0.789751	valid_1's amex_metric: 0.660278
# [3500]	training's amex_metric: 0.809041	valid_1's amex_metric: 0.658352
# [4000]	training's amex_metric: 0.830019	valid_1's amex_metric: 0.66015
# [4500]	training's amex_metric: 0.847396	valid_1's amex_metric: 0.661063
# [5000]	training's amex_metric: 0.864602	valid_1's amex_metric: 0.661553
# [5500]	training's amex_metric: 0.879443	valid_1's amex_metric: 0.661493
# [6000]	training's amex_metric: 0.895898	valid_1's amex_metric: 0.661489
# [6500]	training's amex_metric: 0.910853	valid_1's amex_metric: 0.664045
# [7000]	training's amex_metric: 0.921756	valid_1's amex_metric: 0.660645
# [7500]	training's amex_metric: 0.933923	valid_1's amex_metric: 0.660664
# [8000]	training's amex_metric: 0.944862	valid_1's amex_metric: 0.657788
# [8500]	training's amex_metric: 0.954019	valid_1's amex_metric: 0.65958
# [9000]	training's amex_metric: 0.961202	valid_1's amex_metric: 0.657023
# [9500]	training's amex_metric: 0.967348	valid_1's amex_metric: 0.6588
# [10000]	training's amex_metric: 0.973388	valid_1's amex_metric: 0.658063
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 2 CV score is 0.6580631555210064
#
# --------------------------------------------------
# Training fold 3:-
# X_train shape: (58303, 3019)
# X_valid shape: (14576, 3019)
# X_test shape: (113292, 3019)
# [500]	training's amex_metric: 0.666751	valid_1's amex_metric: 0.63295
# [1000]	training's amex_metric: 0.694355	valid_1's amex_metric: 0.645771
# [1500]	training's amex_metric: 0.718072	valid_1's amex_metric: 0.652055
# [2000]	training's amex_metric: 0.741172	valid_1's amex_metric: 0.656996
# [2500]	training's amex_metric: 0.76709	valid_1's amex_metric: 0.660232
# [3000]	training's amex_metric: 0.791974	valid_1's amex_metric: 0.660685
# [3500]	training's amex_metric: 0.812345	valid_1's amex_metric: 0.664428
# [4000]	training's amex_metric: 0.831236	valid_1's amex_metric: 0.664539
# [4500]	training's amex_metric: 0.848538	valid_1's amex_metric: 0.662854
# [5000]	training's amex_metric: 0.863767	valid_1's amex_metric: 0.6622
# [5500]	training's amex_metric: 0.881358	valid_1's amex_metric: 0.662658
# [6000]	training's amex_metric: 0.89569	valid_1's amex_metric: 0.659893
# [6500]	training's amex_metric: 0.90982	valid_1's amex_metric: 0.661086
# [7000]	training's amex_metric: 0.921643	valid_1's amex_metric: 0.661416
# [7500]	training's amex_metric: 0.933178	valid_1's amex_metric: 0.659124
# [8000]	training's amex_metric: 0.944986	valid_1's amex_metric: 0.657327
# [8500]	training's amex_metric: 0.954357	valid_1's amex_metric: 0.657752
# [9000]	training's amex_metric: 0.962022	valid_1's amex_metric: 0.658962
# [9500]	training's amex_metric: 0.968423	valid_1's amex_metric: 0.659065
# [10000]	training's amex_metric: 0.974436	valid_1's amex_metric: 0.658769
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 3 CV score is 0.658769119534365
#
# --------------------------------------------------
# Training fold 4:-
# X_train shape: (58304, 3019)
# X_valid shape: (14575, 3019)
# X_test shape: (113292, 3019)
# [500]	training's amex_metric: 0.665304	valid_1's amex_metric: 0.642721
# [1000]	training's amex_metric: 0.692596	valid_1's amex_metric: 0.654999
# [1500]	training's amex_metric: 0.715712	valid_1's amex_metric: 0.664214
# [2000]	training's amex_metric: 0.740816	valid_1's amex_metric: 0.66768
# [2500]	training's amex_metric: 0.764594	valid_1's amex_metric: 0.668081
# [3000]	training's amex_metric: 0.791068	valid_1's amex_metric: 0.668592
# [3500]	training's amex_metric: 0.81058	valid_1's amex_metric: 0.66846
# [4000]	training's amex_metric: 0.830885	valid_1's amex_metric: 0.671187
# [4500]	training's amex_metric: 0.849927	valid_1's amex_metric: 0.667824
# [5000]	training's amex_metric: 0.86525	valid_1's amex_metric: 0.668473
# [5500]	training's amex_metric: 0.881162	valid_1's amex_metric: 0.66762
# [6000]	training's amex_metric: 0.896662	valid_1's amex_metric: 0.668033
# [6500]	training's amex_metric: 0.909895	valid_1's amex_metric: 0.669754
# [7000]	training's amex_metric: 0.920763	valid_1's amex_metric: 0.670899
# [7500]	training's amex_metric: 0.931783	valid_1's amex_metric: 0.670819
# [8000]	training's amex_metric: 0.94301	valid_1's amex_metric: 0.671091
# [8500]	training's amex_metric: 0.952224	valid_1's amex_metric: 0.669867
# [9000]	training's amex_metric: 0.959012	valid_1's amex_metric: 0.668937
# [9500]	training's amex_metric: 0.96633	valid_1's amex_metric: 0.669006
# [10000]	training's amex_metric: 0.972963	valid_1's amex_metric: 0.667883
# AxesSubplot(0.125,0.125;0.775x0.755)
# Our fold 4 CV score is 0.6678831788497244

# %%
# Compute out of folds metric
score = amex_metric(Y_train, oof_predictions)
print(f'Our out of folds CV score is {score}')

oof_filename = f'OOFs/oof_lt12_{CFG.mv}_dp{CFG.dpv}{CFG.n_folds}fold_seed{CFG.seed}.csv'
tst_filename = f'PREDs/lgb_lt12_{CFG.mv}_dp{CFG.dpv}{CFG.n_folds}fold_seed{CFG.seed}.csv'

# Create a dataframe to store out of folds predictions
oof_df = pd.DataFrame({'customer_ID': df_train['customer_ID'], 'target': Y_train, 'prediction': oof_predictions})
oof_df.to_csv(oof_filename, index = False)

# Create a dataframe to store test prediction
test_df = pd.DataFrame({'customer_ID': df_test['customer_ID'], 'prediction': test_predictions})
test_df.to_csv(tst_filename, index = False)
print(tst_filename)
# Out:
# Our out of folds CV score is 0.6599943387687806
# PREDs/lgb_lt12_v1_dpv65fold_seed4242.csv

# %%
# !kaggle competitions submit -c amex-default-prediction -f cb_v2_dpv25fold_seed802.csv -m "catboost with \
# 2008 feats CV 7952"
